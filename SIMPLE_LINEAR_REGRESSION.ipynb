# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\DATASETS2\placement.csv")

# %%
df
# Out:
#      cgpa  placed
# 0    7.19       1
# 1    7.46       1
# 2    7.54       1
# 3    6.42       1
# 4    7.23       0
# ..    ...     ...
# 194  8.19       0
# 195  6.71       0
# 196  7.28       1
# 197  6.75       0
# 198  8.29       1
#
# [199 rows x 2 columns]

# %%
df.head()
# Out:
#    cgpa  placed
# 0  7.19       1
# 1  7.46       1
# 2  7.54       1
# 3  6.42       1
# 4  7.23       0

# %%
df.tail()
# Out:
#      cgpa  placed
# 194  8.19       0
# 195  6.71       0
# 196  7.28       1
# 197  6.75       0
# 198  8.29       1

# %%
df.isna()
# Out:
#       cgpa  placed
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False
# ..     ...     ...
# 194  False   False
# 195  False   False
# 196  False   False
# 197  False   False
# 198  False   False
#
# [199 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# cgpa      0
# placed    0
# dtype: int64

# %%
x=df.iloc[:,:1].values
y=df.iloc[:,:-1].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# Visualising the Training set results
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('cgpa vs placed (Training set)')
plt.xlabel('cgpa of student')
plt.ylabel('placed')
plt.show()

# Visualising the Test set results
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('cgpa vs placed (Test set)')
plt.xlabel('cgpa of student')
plt.ylabel('placed')
plt.show()
